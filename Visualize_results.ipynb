# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefix = '30000_epochs_pen0.02_scale1000_'

# %%
PAR = np.load(prefix + 'PAR_list.npy')

# %%
def get_agg(obj, sum_over):
    obj_sum = 0
    obj_list = []
    sum_over = sum_over
    for ii, item in enumerate(obj):
        obj_sum += item
        if ii % sum_over == 0:
            obj_list.append(obj_sum / float(sum_over))
            obj_sum = 0
    obj_agg = np.array(obj_list)
    return obj_agg

# %%
PAR_agg = get_agg(PAR, 300)

# %%
plt.plot(PAR_agg[1:]);

# %%
reward = np.load(prefix + 'reward_list.npy')

# %%
reward
# Out:
# array([-2.04602869, -2.05470665, -2.05057598, ...,  1.95621474,
#        -2.04490577, -2.04468148])

# %%
reward_agg = get_agg(reward, 300)

# %%
plt.plot(reward_agg[1:]);

# %%
Q_change = np.load(prefix + 'Q_change_list.npy')

# %%
Q_change[:]
# Out:
# array([21, 26, 34, ...,  6,  6,  6])

# %%
Q_change_agg = get_agg(Q_change, 300)

# %%
plt.plot(Q_change_agg[1:]);

# %%
max_list = np.load(prefix + 'max_list.npy')

# %%
max_list
# Out:
# array([10.13913   , 10.23862637, 10.19064835, ..., 10.13913   ,
#        10.13913   , 10.13913   ])

# %%
max_list_agg = get_agg(max_list, 300)

# %%
plt.plot(max_list_agg[1:]);

# %%
avg_list = np.load(prefix + 'average_list.npy')

# %%
avg_list
# Out:
# array([9.69297502, 9.70755836, 9.70005836, ..., 9.71380836, 9.70339169,
#        9.70547502])

# %%
avg_list_agg = get_agg(avg_list, 300)

# %%
plt.plot(avg_list_agg[1:]);

# %%
Q = np.load(prefix + 'Q.npy')

# %%
# Q['soc_bin']['hour']['percent_honesty']['action']
Q[0][3][0]
# Out:
# array([-3.990962  , -3.99096664, -3.99342584])

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[0])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_0 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[1])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_1 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_0)
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_1)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_2)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');
