# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefix = '5000_epochs_Q_from_15000_fun_'

# %%
PAR = np.load(prefix + 'PAR_list.npy')

# %%
def get_agg(obj, sum_over):
    obj_sum = 0
    obj_list = []
    sum_over = sum_over
    for ii, item in enumerate(obj):
        obj_sum += item
        if ii % sum_over == 0:
            obj_list.append(obj_sum / float(sum_over))
            obj_sum = 0
    obj_agg = np.array(obj_list)
    return obj_agg

# %%
PAR_agg = get_agg(PAR, 100)

# %%
plt.plot(PAR_agg[1:]);

# %%
reward = np.load(prefix + 'reward_list.npy')

# %%
reward
# Out:
# array([-2.09573379,  1.90377619,  1.90766579, ...,  1.90857792,
#        -2.08418673, -2.06599637])

# %%
reward_agg = get_agg(reward, 100)

# %%
plt.plot(reward_agg[1:]);

# %%
Q_change = np.load(prefix + 'Q_change_list.npy')

# %%
Q_change[:]
# Out:
# array([ 0,  0,  0, ...,  9, 11, 10])

# %%
Q_change_agg = get_agg(Q_change, 100)

# %%
plt.plot(Q_change_agg[1:]);

# %%
max_list = np.load(prefix + 'max_list.npy')

# %%
max_list
# Out:
# array([10534.68197802, 10527.21197802, 10514.36197802, ...,
#        10517.38197802, 10397.2756044 , 10193.8689011 ])

# %%
max_list_agg = get_agg(max_list, 100)

# %%
plt.plot(max_list_agg[1:]);

# %%
avg_list = np.load(prefix + 'average_list.npy')

# %%
avg_list
# Out:
# array([9614.27136996, 9603.15936996, 9625.5907033 , ..., 9636.40203663,
#        9589.9307033 , 9562.76136996])

# %%
avg_list_agg = get_agg(avg_list, 100)

# %%
plt.plot(avg_list_agg[1:]);

# %%
Q = np.load(prefix + 'Q.npy')

# %%
# Q['soc_bin']['hour']['percent_honesty']['action']
Q[0][3][0]
# Out:
# array([-4.40970555, -5.04519262, -4.97510502])

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[0])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_0 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[1])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_1 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_0)
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_1)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_2)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
Q_list = np.load('5000_epochs_pen001' + '_Q_list.npy')
Q_list[4]
# Out:
# array([[[[-5.53893327, -5.53475285, -5.5407782 ],
#          [-5.50709009, -5.50500332, -5.52169002],
#          [-5.61356777, -5.6175009 , -5.62160203]],
#
#         [[-5.47335594, -5.46860289, -5.46986135],
#          [-5.4626571 , -5.46387188, -5.46156632],
#          [-5.52635939, -5.51976282, -5.52262017]],
#
#         [[-5.32664595, -5.32244714, -5.32151114],
#          [-5.27011981, -5.27524739, -5.27432405],
