# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefix = '60000_epochs_pen0.2_scale1000_adaptive_alpha_'

# %%
average_over = 600

# %%
PAR = np.load(prefix + 'PAR_list.npy')

# %%
def get_agg(obj, sum_over):
    obj_sum = 0
    obj_list = []
    sum_over = sum_over
    for ii, item in enumerate(obj):
        obj_sum += item
        if ii % sum_over == 0:
            obj_list.append(obj_sum / float(sum_over))
            obj_sum = 0
    obj_agg = np.array(obj_list)
    return obj_agg

# %%
PAR_agg = get_agg(PAR, average_over)

# %%
plt.plot(PAR_agg[1:]);

# %%
reward = np.load(prefix + 'reward_list.npy')

# %%
reward
# Out:
# array([-2.12657734, -2.12444601, -2.14037883, ...,  1.88234792,
#         1.86282326,  1.85875424])

# %%
reward_agg = get_agg(reward, average_over)

# %%
plt.plot(reward_agg[1:]);

# %%
Q_change = np.load(prefix + 'Q_change_list.npy')

# %%
Q_change[:]
# Out:
# array([19, 22, 24, ...,  0,  0,  0])

# %%
Q_change_agg = get_agg(Q_change, average_over)

# %%
plt.plot(Q_change_agg[1:]);

# %%
max_list = np.load(prefix + 'max_list.npy')

# %%
max_list
# Out:
# array([10.9043956 , 10.8743956 , 11.1600989 , ..., 11.09602198,
#        11.29602198, 11.29602198])

# %%
max_list_agg = get_agg(max_list, average_over)

# %%
plt.plot(max_list_agg[1:]);

# %%
avg_list = np.load(prefix + 'average_list.npy')

# %%
avg_list
# Out:
# array([9.67922502, 9.67089169, 9.78630836, ..., 9.92797502, 9.93339169,
#        9.89797502])

# %%
avg_list_agg = get_agg(avg_list, average_over)

# %%
plt.plot(avg_list_agg[1:]);

# %%
Q = np.load(prefix + 'Q.npy')

# %%
# Q['soc_bin']['hour']['percent_honesty']['action']
Q[0][3][0]
# Out:
# array([-4.77572496, -4.0485375 , -4.7880987 ])

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[0])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_0 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[1])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_1 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_0)
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_1)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_2)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
Q = np.load(prefix + 'Q_list.npy')
Q = Q[int(0.4*60)]
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)
print(l_Q1_2)
plt.imshow(l_Q1_2);
# Out:
# [[2 1 2 2 2 1 2 2 1 1 0 0 0 0 0]
#  [2 2 1 2 1 0 0 2 0 1 2 2 0 0 0]
#  [1 2 2 2 2 1 1 2 2 2 2 2 0 2 0]
#  [0 0 0 0 1 0 0 2 2 0 0 0 2 0 0]]

# %%
Q = np.load(prefix + 'Q_list.npy')
Q = Q[int(0.8*60)]
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)
print(l_Q1_2)
plt.imshow(l_Q1_2);
# Out:
# [[2 1 2 2 2 2 2 2 2 0 0 2 0 0 0]
#  [2 2 2 1 0 2 2 0 2 0 0 0 0 0 0]
#  [0 0 2 0 2 2 1 0 1 2 1 1 0 2 0]
#  [1 1 0 0 0 2 1 0 2 2 2 2 0 1 0]]

# %%
Q[3]
# Out:
# array([[[-7.90290587, -7.4413524 , -7.88595269],
#         [-7.44162753, -7.91235951, -7.91161223],
#         [-7.92460093, -7.45078212, -7.90795423]],
#
#        [[-6.34545324, -6.93559982, -6.95251295],
#         [-6.95636684, -6.34833681, -6.94625921],
#         [-6.96628318, -6.35365658, -6.9725518 ]],
#
#        [[-5.28816587, -5.98338054, -5.96144331],
#         [-5.99082708, -5.26324455, -6.00364137],
#         [-5.26251996, -6.00076505, -5.96115212]],
#
#        [[-5.00952527, -4.99480723, -4.19623682],
#         [-5.05825878, -5.0191406 , -4.20677844],
#         [-4.19973161, -5.03037761, -4.98558639]],
#
#        [[-4.06129573, -3.13347886, -4.07720705],
#         [-3.13546019, -4.14440318, -4.02996749],
#         [-3.13814734, -4.10540249, -4.10569497]],
#
#        [[-3.17721232, -2.07457394, -3.16698659],
#         [-3.21037027, -3.15116655, -2.07880122],
#         [-3.12281859, -3.128053  , -2.0738927 ]],
#
#        [[-1.01252329, -2.30911699, -2.29414624],
#         [-1.01003287, -2.19161639, -2.41927977],
#         [-2.30565408, -1.01756998, -2.3263233 ]],
#
#        [[-1.30113222,  0.05145986, -1.30955453],
#         [ 0.05234648, -1.38884579, -1.46041136],
#         [ 0.05924025, -1.3498831 , -1.41558688]],
#
#        [[-0.59417324,  1.13423027, -0.42275138],
#         [-0.58689945, -0.70993032,  1.13963902],
#         [-0.54418934, -0.6147343 ,  1.13158882]],
#
#        [[ 0.25204041,  2.2310435 ,  0.38374987],
#         [ 0.06137679,  0.19376565,  2.22817134],
#         [ 0.1353461 ,  0.25070683,  2.22954171]],
#
#        [[ 0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ],
#         [ 2.58520544,  2.56362598,  3.32218908]],
#
#        [[ 0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ],
#         [ 3.65797457,  3.60522745,  4.37939674]],
#
#        [[ 0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ],
#         [ 5.42768457,  4.66965501,  4.69883159]],
#
#        [[ 0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ],
#         [ 2.76488709,  3.51361225,  2.91267547]],
#
#        [[ 0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ],
#         [ 1.64365248,  1.29494946,  1.21144952]]])
