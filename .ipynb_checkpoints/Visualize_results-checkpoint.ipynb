# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 15, 7

# %%
prefix = '1000000_epochs_pen0.4_scale1000_adaptive_'

# %%
average_over = 300

# %%
PAR = np.load(prefix + 'PAR_list.npy')

# %%
def get_agg(obj, sum_over):
    obj_sum = 0
    obj_list = []
    sum_over = sum_over
    for ii, item in enumerate(obj):
        obj_sum += item
        if ii % sum_over == 0:
            obj_list.append(obj_sum / float(sum_over))
            obj_sum = 0
    obj_agg = np.array(obj_list)
    return obj_agg

# %%
PAR_agg = get_agg(PAR[400000:430000], average_over)

# %%
plt.plot(PAR_agg[1:]);

# %%
reward = np.load(prefix + 'reward_list.npy')

# %%
reward
# Out:
# array([ 1.77096086, -2.33093521, -2.27272975, ...,  1.77841413,
#        -2.26091539,  1.78101633])

# %%
reward_agg = get_agg(reward[400000:430000], average_over)

# %%
plt.plot(reward_agg[1:]);

# %%
Q_change = np.load(prefix + 'Q_change_list.npy')

# %%
Q_change[:]
# Out:
# array([24, 29, 28, ...,  4,  3,  4])

# %%
Q_change_agg = get_agg(Q_change[400000:430000], average_over)

# %%
plt.plot(Q_change_agg[1:]);

# %%
max_list = np.load(prefix + 'max_list.npy')

# %%
max_list
# Out:
# array([12.7023956 , 13.6800989 , 12.75387912, ..., 13.51602198,
#        13.27602198, 13.43602198])

# %%
max_list_agg = get_agg(max_list[0:30000], average_over)

# %%
plt.plot(max_list_agg[1:]);

# %%
avg_list = np.load(prefix + 'average_list.npy')

# %%
avg_list
# Out:
# array([ 9.90047502, 10.21130836,  9.79797502, ...,  9.91547502,
#        10.28547502, 10.07172502])

# %%
avg_list_agg = get_agg(avg_list[:30000], average_over)

# %%
plt.plot(avg_list_agg[1:]);

# %%
Q = np.load(prefix + 'Q.npy')

# %%
# Q['soc_bin']['hour']['percent_honesty']['action']
Q[0][3][0]
# Out:
# array([-4.05248974, -4.04704116, -3.80658507])

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[0])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_0 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[1])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_1 = np.array(l_2)

# %%
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_0)
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_1)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
fig, ax = plt.subplots(figsize=(15, 8))
im = ax.imshow(l_Q1_2)
#cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])
#fig.colorbar(im, cax=cax, orientation='horizontal');

# %%
Q = np.load(prefix + 'Q_list.npy')
Q = Q[18]
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)
print(l_Q1_2)
plt.imshow(l_Q1_2);
# Out:
# [[0 2 1 2 2 0 0 2 0 0 1 0 0 0 0]
#  [1 2 1 2 2 2 1 2 2 2 0 0 2 0 0]
#  [2 2 2 1 0 0 1 2 0 2 1 0 0 0 0]
#  [2 2 1 1 0 1 2 2 1 1 0 0 2 2 1]]

# %%
Q = np.load(prefix + 'Q_list.npy')
Q = Q[19]
l_2 = []
for row in Q:
    l = []
    for column in row:
        max_action = np.argmax(column[2])
        l.append(max_action)
    l_2.append(np.array(l))
l_Q1_2 = np.array(l_2)
print(l_Q1_2)
plt.imshow(l_Q1_2);
# Out:
# [[0 2 1 2 2 0 0 2 0 0 1 0 0 0 0]
#  [1 2 1 2 2 2 1 2 2 2 0 0 2 0 0]
#  [2 2 2 1 0 0 1 2 0 2 1 0 0 0 0]
#  [2 2 1 1 0 1 2 2 1 1 0 0 2 2 1]]

# %%
Q[3]
# Out:
# array([[[-8.25756808e+00, -8.19753291e+00, -7.45818303e+00],
#         [-7.48862223e+00, -8.19044450e+00, -8.21454133e+00],
#         [-8.20935695e+00, -8.24057087e+00, -7.47154939e+00]],
#
#        [[-6.28433900e+00, -7.16496468e+00, -7.15342649e+00],
#         [-7.14421614e+00, -7.22227454e+00, -6.29626441e+00],
#         [-7.13916699e+00, -7.20354093e+00, -6.31951474e+00]],
#
#        [[-6.12126486e+00, -6.16847585e+00, -5.11653554e+00],
#         [-5.12072372e+00, -6.17563003e+00, -6.11908679e+00],
#         [-6.17131755e+00, -5.12458550e+00, -6.09123479e+00]],
#
#        [[-5.16842784e+00, -5.13531751e+00, -3.95833941e+00],
#         [-5.02844883e+00, -5.18736380e+00, -3.96314743e+00],
#         [-5.10038741e+00, -3.95831643e+00, -5.07054278e+00]],
#
#        [[-4.10419046e+00, -4.11024503e+00, -2.83804909e+00],
#         [-4.07091113e+00, -2.82738941e+00, -4.18945581e+00],
#         [-2.82394092e+00, -4.12510772e+00, -4.06588098e+00]],
#
#        [[-3.04907346e+00, -1.73475067e+00, -3.07102832e+00],
#         [-3.02831076e+00, -1.73299434e+00, -2.99968465e+00],
#         [-3.16537858e+00, -1.73414073e+00, -3.06803714e+00]],
#
#        [[-6.69745635e-01, -2.12934874e+00, -1.92013484e+00],
#         [-6.70505739e-01, -2.00435597e+00, -2.05061017e+00],
#         [-1.97479658e+00, -2.03619888e+00, -6.69939675e-01]],
#
#        [[-9.44821871e-01, -8.74222116e-01,  3.80074781e-01],
#         [-1.01930961e+00, -9.57102298e-01,  3.82203314e-01],
#         [-1.04482291e+00, -7.54951201e-01,  3.81653281e-01]],
#
#        [[-7.98396684e-02,  1.43421979e+00, -1.39536144e-03],
#         [ 1.43250961e+00,  1.01408903e-01,  1.75617593e-02],
#         [ 8.78516519e-02,  1.43648681e+00,  1.62002125e-01]],
#
#        [[ 2.48510781e+00,  1.23163641e+00,  9.88977473e-01],
#         [ 2.49025324e+00,  1.12678495e+00,  9.33654453e-01],
#         [ 1.16974982e+00,  2.48876193e+00,  1.12005148e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 3.52970993e+00,  2.96082278e+00,  3.01742654e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.56366049e+00,  3.99438684e+00,  4.07118631e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 4.99579252e+00,  4.88989038e+00,  5.58916325e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.96055609e+00,  3.04451126e+00,  3.61270024e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.18247717e+00,  1.75778130e+00,  1.24779413e+00]]])
